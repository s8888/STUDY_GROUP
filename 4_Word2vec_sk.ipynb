# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = f.namelist() # list type, element is str "text8" 
        data = f.read(data[0]) #read data as bytes type
        data = tf.compat.as_str(data) #change bytes to str
        data = data.split() # split str with space
        print('Data size %d' % len(data))
    return data

# %%
# Read data
filename = './data/text8.zip'
words = read_data(filename)
# Out:
# Data size 17005207

# %%
def build_dataset(words, vocabulary_size):
    count = [['UNK', -1]] # unknow words
    # count each words and list as tuple (word, count)
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary) #dict name is word and contest is the index
    data = list() # context is same as words list but transfer to dictionary index
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

# %%
vocabulary_size = 50000

data, count, dictionary, reverse_dictionary = build_dataset(words, vocabulary_size)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print('words list',words[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]
# words list ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
def generate_batch(batch_size, num_skips, skip_window):
    global data_index #global variable
    assert batch_size % num_skips == 0 #make sure batch_size is even
    assert num_skips <= 2 * skip_window 
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])# for shifting window in line 24
        data_index = (data_index + 1) % len(data)
    ############################################    
    for i in range(batch_size // num_skips):
        target = skip_window  # index which will be picked as buffer[index] for label matrix
        targets_to_avoid = [ skip_window ] # those indexs will no be picked for lable
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1) #exclude target already in target_to_avoid
            targets_to_avoid.append(target) #add picked target to avoid be picked again
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
    ############################################
        buffer.append(data[data_index]) # shift window to right direct with 1 index
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])
############################################
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
############################################
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'of', 'as', 'originated', 'term']

# %%
batch_size = 128
# Skip-gram arguments
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
"""
We pick a random validation set to sample nearest neighbors. here we limit the
validation samples to the words that have a low numeric ID, which by
construction are also the most frequent. 
"""
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
 
with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
     
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
     
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
     
    # Compute the softmax loss (tensor mean), using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
   
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    #optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
     
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
    print (normalized_embeddings.get_shape)
# Out:
# <bound method Tensor.get_shape of <tf.Tensor 'truediv:0' shape=(50000, 128) dtype=float32>>

# %%
num_steps = 100001
 
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1] # argsort function is sorting from small to big 
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.181067
# Nearest to his: kaplan, bram, wally, interlaced, forward, mentor, increased, mortally,
# Nearest to six: climber, marlborough, szab, forested, peas, chih, underarm, jovian,
# Nearest to war: babbage, paulsen, asher, criterion, idiomatic, crudely, creams, columbia,
# Nearest to to: phenols, comit, algal, diets, navigated, rogues, pontius, bodyguards,
# Nearest to when: ringo, roden, sumner, bernese, bean, planetary, legally, borgia,
# Nearest to had: bogside, neural, plunder, disadvantaged, addictive, spies, elbridge, jacobite,
# Nearest to used: unfaithful, flask, defeated, internalism, semiotics, intuitively, climactic, radicals,
# Nearest to not: geddy, minority, conducted, reduplication, pubescent, consorts, reservation, adventurous,
# Nearest to d: sharper, thoth, bosworth, herse, cigarette, ulrich, devout, quaternion,
# Nearest to of: lingo, bless, ica, thanking, gilgamesh, mashiach, abaci, jura,
# Nearest to which: wardens, asymmetric, ruin, proliferate, denslow, odore, nutshell, goeldi,
# Nearest to an: exclusive, tierra, portmanteaus, calm, hwang, cheers, assessed, deccan,
# Nearest to for: secreting, porous, realised, murderer, codon, leroy, poetess, definable,
# Nearest to their: aikidoka, summarized, evenly, scotsman, narrower, consultation, presupposes, bolland,
# Nearest to its: nemo, aria, aeneas, hing, corpse, parallel, taxi, cve,
# Nearest to there: friuli, advanced, flatus, creams, eases, linen, hedwig, syncopated,
# Average loss at step 2000: 4.841755
# Average loss at step 4000: 4.146494
# Average loss at step 6000: 4.033161
# Average loss at step 8000: 3.908563
# Average loss at step 10000: 3.816612
# Nearest to his: the, articulate, its, their, forward, deforestation, it, relinquish,
# Nearest to six: szab, three, climber, marlborough, incite, zero, maliki, four,
# Nearest to war: paulsen, babbage, bull, criterion, chaney, twinned, asher, idiomatic,
# Nearest to to: in, phenols, reynolds, babysitter, copyleft, algal, that, shiragami,
# Nearest to when: sumner, roden, preferred, bernese, legally, bean, kerry, calvert,
# Nearest to had: has, have, neural, smaller, after, cladistic, rebuilt, addictive,
# Nearest to used: pirandello, unfaithful, intuitively, shards, defeated, inalienable, flask, semiotics,
# Nearest to not: pissarro, monasteries, bard, frog, emotional, reoccupied, consorts, conducted,
# Nearest to d: hammers, thoth, devout, inclination, sharper, heaven, herse, rearmament,
# Nearest to of: and, in, for, aching, on, s, from, first,
# Nearest to which: nutshell, mas, criteria, an, that, it, dana, manchester,
# Nearest to an: the, it, any, chung, mael, bastiat, dogged, which,
# Nearest to for: of, secreting, with, and, managerial, codon, un, yucat,
# Nearest to their: the, aikidoka, a, his, scotsman, presupposes, this, summarized,
# Nearest to its: the, his, nemo, cve, hing, a, lingua, bluish,
# Nearest to there: friuli, flatus, advanced, he, shanghai, meters, watt, subjugating,
# Average loss at step 12000: 3.784011
# Average loss at step 14000: 3.739503
# Average loss at step 16000: 3.566901
# Average loss at step 18000: 3.618500
# Average loss at step 20000: 3.708525
# Nearest to his: the, their, its, articulate, forward, this, rigs, relinquish,
# Nearest to six: nine, eight, three, five, four, zero, two, january,
# Nearest to war: paulsen, bull, babbage, idiomatic, asher, chaney, twinned, criterion,
# Nearest to to: reynolds, phenols, copyleft, for, in, under, again, pontius,
# Nearest to when: was, where, preferred, roden, sumner, legally, bernese, agrees,
# Nearest to had: has, have, was, neural, rebuilt, cladistic, after, diesel,
# Nearest to used: pirandello, intuitively, defeated, unfaithful, flask, climactic, agni, depictions,
# Nearest to not: also, bard, conducted, considered, they, frog, pissarro, monasteries,
# Nearest to d: b, hammers, thoth, inclination, devout, jumaada, undergoes, herse,
# Nearest to of: in, and, for, aching, from, horthy, jura, with,
# Nearest to which: that, this, who, it, nutshell, mas, and, many,
# Nearest to an: the, any, mael, it, bastiat, chung, assessed, dogged,
# Nearest to for: with, of, and, secreting, by, in, as, bahri,
# Nearest to their: his, the, aikidoka, presupposes, a, this, scotsman, its,
# Nearest to its: the, his, this, nemo, their, cve, suddenly, dsn,
# Nearest to there: flatus, he, friuli, it, shanghai, advanced, meters, subjugating,
# Average loss at step 22000: 3.669686
# Average loss at step 24000: 3.650672
# Average loss at step 26000: 3.637872
# Average loss at step 28000: 3.620493
# Average loss at step 30000: 3.656895
# Nearest to his: their, the, its, articulate, s, forward, glut, relinquish,
# Nearest to six: eight, four, nine, three, five, seven, two, zero,
# Nearest to war: paulsen, bull, babbage, asher, chaney, idiomatic, criterion, fairway,
# Nearest to to: for, phenols, can, under, would, in, copyleft, again,
# Nearest to when: where, was, legally, later, roden, preferred, sumner, since,
# Nearest to had: have, has, was, cladistic, diesel, bubbled, neural, after,
# Nearest to used: intuitively, defeated, pirandello, irvin, known, usually, greats, climactic,
# Nearest to not: they, bard, also, conducted, barring, never, considered, frog,
# Nearest to d: b, hammers, thoth, inclination, jumaada, herse, devout, pmod,
# Nearest to of: in, and, for, from, aching, under, against, anni,
# Nearest to which: that, this, it, who, nutshell, lovecraftian, lancashire, mas,
# Nearest to an: any, the, it, mael, arunachal, dogged, assessed, bastiat,
# Nearest to for: of, with, in, secreting, by, to, and, as,
# Nearest to their: his, the, its, presupposes, aikidoka, this, a, gomes,
# Nearest to its: the, his, their, this, cve, suddenly, nemo, a,
# Nearest to there: it, he, flatus, they, friuli, shanghai, supermodel, subjugating,
# Average loss at step 32000: 3.646356
# Average loss at step 34000: 3.644496
# Average loss at step 36000: 3.605035
# Average loss at step 38000: 3.482377
# Average loss at step 40000: 3.575671
# Nearest to his: their, its, the, articulate, her, s, glut, forward,
# Nearest to six: eight, three, four, five, seven, nine, two, zero,
# Nearest to war: paulsen, bull, chaney, babbage, asher, idiomatic, criterion, creep,
# Nearest to to: for, phenols, reynolds, can, copyleft, javelin, shiragami, would,
# Nearest to when: where, was, since, legally, roden, preferred, later, myelogenous,
# Nearest to had: has, have, was, cladistic, diesel, bubbled, rebuilt, been,
# Nearest to used: known, intuitively, irvin, defeated, able, usually, refuses, pirandello,
# Nearest to not: never, conducted, they, bard, also, it, barring, maintenance,
# Nearest to d: UNK, b, hammers, thoth, herse, inclination, jumaada, pmod,
# Nearest to of: in, for, jura, aching, during, from, broadcasted, between,
# Nearest to which: that, this, it, who, also, lancashire, nutshell, lovecraftian,
# Nearest to an: any, the, arunachal, engines, mael, assessed, takla, wolfgang,
# Nearest to for: secreting, with, of, to, aylwin, bahri, southwark, yucat,
# Nearest to their: his, its, the, presupposes, aikidoka, any, calvinists, this,
# Nearest to its: the, their, his, any, foreigner, this, suddenly, moabite,
# Nearest to there: it, he, they, shanghai, flatus, friuli, supermodel, always,
# Average loss at step 42000: 3.575889
# Average loss at step 44000: 3.590951
# Average loss at step 46000: 3.583803
# Average loss at step 48000: 3.498603
# Average loss at step 50000: 3.521296
# Nearest to his: their, its, the, articulate, s, her, glut, rigs,
# Nearest to six: eight, four, three, five, seven, nine, two, zero,
# Nearest to war: paulsen, asher, bull, chaney, babbage, idiomatic, creep, twinned,
# Nearest to to: phenols, reynolds, censor, copyleft, would, could, under, again,
# Nearest to when: where, since, was, legally, if, preferred, myelogenous, uk,
# Nearest to had: has, have, was, cladistic, were, diesel, after, bubbled,
# Nearest to used: known, able, defeated, irvin, possible, usually, intuitively, orientalis,
# Nearest to not: never, conducted, bard, also, nor, maintenance, they, barring,
# Nearest to d: b, hammers, thoth, herse, jumaada, pmod, inclination, devout,
# Nearest to of: in, and, phonemically, anni, ncp, for, dalton, aching,
# Nearest to which: that, this, who, it, also, and, lancashire, what,
# Nearest to an: any, arunachal, marched, engines, assessed, takla, dogged, bastiat,
# Nearest to for: secreting, with, bahri, basic, by, historical, aylwin, of,
# Nearest to their: his, its, the, presupposes, catalysed, any, her, calvinists,
# Nearest to its: their, the, his, foreigner, any, moabite, suddenly, cve,
# Nearest to there: it, they, he, shanghai, supermodel, friuli, always, flatus,
# Average loss at step 52000: 3.571904
# Average loss at step 54000: 3.564130
# Average loss at step 56000: 3.564779
# Average loss at step 58000: 3.537479
# Average loss at step 60000: 3.534528
# Nearest to his: their, its, her, the, articulate, s, glut, darpa,
# Nearest to six: eight, five, four, three, seven, nine, zero, two,
# Nearest to war: paulsen, asher, chaney, bull, babbage, idiomatic, creep, mlp,
# Nearest to to: would, for, could, not, heisei, phenols, reynolds, copyleft,
# Nearest to when: where, was, if, since, legally, after, uk, coincidence,
# Nearest to had: has, have, was, cladistic, were, diesel, bubbled, after,
# Nearest to used: known, able, possible, orientalis, irvin, intuitively, defeated, unfaithful,
# Nearest to not: never, they, it, nor, to, maintenance, bard, also,
# Nearest to d: b, hammers, herse, thoth, jumaada, pmod, inclination, sharper,
# Nearest to of: for, in, jura, throughout, and, leq, depose, aching,
# Nearest to which: that, this, who, what, also, it, lancashire, but,
# Nearest to an: arunachal, engines, marched, any, assessed, bastiat, takla, wolfgang,
# Nearest to for: of, secreting, historical, to, bahri, basic, with, absentia,
# Nearest to their: his, its, the, her, presupposes, calvinists, catalysed, some,
# Nearest to its: their, his, the, any, foreigner, her, suddenly, cve,
# Nearest to there: it, they, he, shanghai, supermodel, always, still, friuli,
# Average loss at step 62000: 3.407562
# Average loss at step 64000: 3.410447
# Average loss at step 66000: 3.548111
# Average loss at step 68000: 3.530597
# Average loss at step 70000: 3.495746
# Nearest to his: their, its, her, articulate, the, glut, s, darpa,
# Nearest to six: eight, four, seven, five, three, nine, zero, two,
# Nearest to war: paulsen, asher, chaney, idiomatic, babbage, bull, creep, junta,
# Nearest to to: for, would, could, must, can, reynolds, heisei, phenols,
# Nearest to when: where, if, was, legally, after, since, peacekeeping, curly,
# Nearest to had: has, have, was, were, cladistic, diesel, after, been,
# Nearest to used: known, orientalis, possible, able, irvin, intuitively, defeated, refuses,
# Nearest to not: never, nor, goodyear, they, yahweh, also, typically, only,
# Nearest to d: b, hammers, thoth, herse, sharper, jumaada, pmod, inclination,
# Nearest to of: for, in, throughout, jura, corporatist, and, depose, pune,
# Nearest to which: that, this, who, it, also, what, but, lancashire,
# Nearest to an: arunachal, engines, takla, the, assessed, any, bastiat, wolfgang,
# Nearest to for: of, bahri, in, to, basic, hybrid, secreting, initial,
# Nearest to their: his, its, the, her, calvinists, presupposes, catalysed, some,
# Nearest to its: their, his, the, any, foreigner, her, steamer, taxi,
# Nearest to there: they, it, he, shanghai, supermodel, still, always, dull,
# Average loss at step 72000: 3.514918
# Average loss at step 74000: 3.484620
# Average loss at step 76000: 3.451629
# Average loss at step 78000: 3.492247
# Average loss at step 80000: 3.511519
# Nearest to his: their, its, her, articulate, the, rigs, glut, s,
# Nearest to six: five, eight, seven, four, three, nine, two, zero,
# Nearest to war: paulsen, asher, chaney, idiomatic, babbage, bull, junta, criterion,
# Nearest to to: would, copyleft, phenols, could, for, javelin, reynolds, schoolgirl,
# Nearest to when: where, if, after, legally, since, was, before, coincidence,
# Nearest to had: has, have, was, were, cladistic, diesel, after, been,
# Nearest to used: known, orientalis, able, possible, irvin, intuitively, defeated, ambience,
# Nearest to not: never, nor, it, they, typically, goodyear, yahweh, norfolk,
# Nearest to d: b, hammers, thoth, herse, jumaada, sharper, cesar, gcc,
# Nearest to of: in, broadcasted, from, throughout, jura, aching, disruptive, anni,
# Nearest to which: that, this, who, also, it, what, but, lancashire,
# Nearest to an: arunachal, takla, engines, bastiat, dedicating, marched, wolfgang, sex,
# Nearest to for: bahri, hybrid, basic, absentia, secreting, initial, southwark, historical,
# Nearest to their: his, its, the, her, catalysed, calvinists, presupposes, some,
# Nearest to its: their, his, the, any, foreigner, her, steamer, moabite,
# Nearest to there: they, it, he, shanghai, supermodel, elected, dull, which,
# Average loss at step 82000: 3.532368
# Average loss at step 84000: 3.532876
# Average loss at step 86000: 3.506031
# Average loss at step 88000: 3.483497
# Average loss at step 90000: 3.494153
# Nearest to his: their, its, her, articulate, s, the, glut, rigs,
# Nearest to six: eight, seven, five, four, three, nine, two, zero,
# Nearest to war: paulsen, idiomatic, asher, chaney, babbage, bull, creep, criterion,
# Nearest to to: would, phenols, javelin, reynolds, scarred, could, will, soir,
# Nearest to when: where, if, after, before, since, legally, peacekeeping, with,
# Nearest to had: has, have, was, were, cladistic, diesel, after, pierrot,
# Nearest to used: known, orientalis, possible, able, present, intuitively, defeated, irvin,
# Nearest to not: never, nor, they, it, still, typically, only, quite,
# Nearest to d: b, hammers, herse, thoth, pmod, jumaada, sharper, inclination,
# Nearest to of: in, for, throughout, aching, from, broadcasted, during, corporatist,
# Nearest to which: that, this, but, who, also, what, it, often,
# Nearest to an: arunachal, bastiat, takla, engines, marched, dedicating, wolfgang, porky,
# Nearest to for: of, with, basic, bahri, secreting, absentia, hybrid, initial,
# Nearest to their: its, his, her, the, catalysed, calvinists, presupposes, some,
# Nearest to its: their, his, the, any, her, foreigner, taxi, moabite,
# Nearest to there: they, it, he, shanghai, supermodel, which, still, dull,
# Average loss at step 92000: 3.527084
# Average loss at step 94000: 3.403949
# Average loss at step 96000: 3.485266
# Average loss at step 98000: 3.382914
# Average loss at step 100000: 3.483952
# Nearest to his: their, her, its, the, s, articulate, glut, rigs,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to war: paulsen, asher, idiomatic, chaney, creep, bull, babbage, flashback,
# Nearest to to: would, phenols, must, can, will, javelin, might, could,
# Nearest to when: where, if, after, before, legally, since, while, peacekeeping,
# Nearest to had: has, have, was, were, cladistic, diesel, after, pierrot,
# Nearest to used: known, orientalis, possible, able, written, present, seen, intuitively,
# Nearest to not: never, nor, only, they, typically, it, yahweh, quite,
# Nearest to d: b, hammers, herse, thoth, la, sharper, jumaada, inclination,
# Nearest to of: in, throughout, including, broadcasted, cole, from, and, corporatist,
# Nearest to which: that, this, but, what, who, also, it, these,
# Nearest to an: arunachal, takla, the, engines, bastiat, adel, marched, musica,
# Nearest to for: with, dogbert, basic, absentia, hybrid, secreting, bahri, initial,
# Nearest to their: its, his, her, the, catalysed, calvinists, some, presupposes,
# Nearest to its: their, his, the, her, any, foreigner, steamer, moabite,
# Nearest to there: they, it, he, shanghai, supermodel, still, now, dull,

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

# %%
num_points = 400
 
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
  
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
